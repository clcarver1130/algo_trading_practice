# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# !pip install yfinance --upgrade --no-cache-dir
# !pip install pandas-datareader
# !pip install fix-yahoo-finance
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
from collections import deque
import random
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()

# %%
yf.pdr_override('INFY')
df_full = pdr.get_data_yahoo("INFY", start="2018-01-01").reset_index()
df_full.to_csv('INFY.csv',index=False)
df_full.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date   High    Low   Open  Close      Volume  Adj Close
# 0 2018-01-02  8.195  8.115  8.135  8.145  12298200.0   7.352555
# 1 2018-01-03  8.135  8.050  8.120  8.075  10250800.0   7.289364
# 2 2018-01-04  8.100  8.010  8.100  8.025  16272000.0   7.244229
# 3 2018-01-05  8.190  8.075  8.085  8.175   9813600.0   7.379634
# 4 2018-01-08  8.260  8.170  8.190  8.240  11198200.0   7.438310

# %%
df= df_full.copy()
name = 'Q-learning agent'
class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []
        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())
    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-10-acb71f3579eb>:22: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /Users/Cameron/miniconda3/envs/personal/lib/python3.7/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# epoch: 10, total rewards: 223.000005.3, cost: 0.005521, total money: 9331.460010
# epoch: 20, total rewards: 216.455005.3, cost: 0.005794, total money: 9245.075010
# epoch: 30, total rewards: 238.315003.3, cost: 0.005630, total money: 9235.505007
# epoch: 40, total rewards: 185.845006.3, cost: 0.004462, total money: 9371.285012
# epoch: 50, total rewards: 219.730005.3, cost: 0.004487, total money: 9347.220010
# epoch: 60, total rewards: 215.060004.3, cost: 0.003968, total money: 9398.620011
# epoch: 70, total rewards: 205.105005.3, cost: 0.003514, total money: 9446.995012
# epoch: 80, total rewards: 226.195004.3, cost: 0.004191, total money: 9316.725009
# epoch: 90, total rewards: 192.605002.3, cost: 0.003324, total money: 9434.495009
# epoch: 100, total rewards: 210.500003.3, cost: 0.003233, total money: 9416.700010
# epoch: 110, total rewards: 214.185006.3, cost: 0.003862, total money: 9304.715010
# epoch: 120, total rewards: 213.075004.3, cost: 0.003297, total money: 9380.245010
# epoch: 130, total rewards: 220.720007.3, cost: 0.003403, total money: 9307.240012
# epoch: 140, total rewards: 218.485008.3, cost: 0.003168, total money: 9364.235013
# epoch: 150, total rewards: 180.430005.3, cost: 0.002767, total money: 9422.320012
# epoch: 160, total rewards: 207.400004.3, cost: 0.002846, total money: 9390.960011
# epoch: 170, total rewards: 203.375003.3, cost: 0.002985, total money: 9349.125009
# epoch: 180, total rewards: 195.585008.3, cost: 0.003031, total money: 9325.675012
# epoch: 190, total rewards: 205.635005.3, cost: 0.003314, total money: 9259.895009
# epoch: 200, total rewards: 203.625004.3, cost: 0.003194, total money: 9262.735007

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
fig = plt.figure(figsize = (20,10))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()
# Out:
# day 6: buy 1 unit at price 8.495000, total balance 9991.505000
# day 7: buy 1 unit at price 8.635000, total balance 9982.870000
# day 8, sell 1 unit at price 8.405000, investment -1.059449 %, total balance 9991.275000,
# day 9, sell 1 unit at price 8.890000, investment 2.953099 %, total balance 10000.165000,
# day 10: buy 1 unit at price 9.060000, total balance 9991.105000
# day 11, sell 1 unit at price 8.960000, investment -1.103757 %, total balance 10000.065000,
# day 12: buy 1 unit at price 8.995000, total balance 9991.070000
# day 13: buy 1 unit at price 9.145000, total balance 9981.924999
# day 14: buy 1 unit at price 9.225000, total balance 9972.699999
# day 15, sell 1 unit at price 9.230000, investment 2.612559 %, total balance 9981.929998,
# day 16: buy 1 unit at price 9.225000, total balance 9972.704998
# day 18: buy 1 unit at price 9.275000, total balance 9963.429998
# day 19: buy 1 unit at price 9.125000, total balance 9954.304998
# day 20: buy 1 unit at price 9.005000, total balance 9945.299998
# day 21, sell 1 unit at price 8.965000, investment -1.968292 %, total balance 9954.264998,
# day 22: buy 1 unit at price 8.875000, total balance 9945.389998
# day 23, sell 1 unit at price 8.685000, investment -5.853658 %, total balance 9954.074999,
# day 25: buy 1 unit at price 8.740000, total balance 9945.334999
# day 26: buy 1 unit at price 8.555000, total balance 9936.779999
# day 27: buy 1 unit at price 8.680000, total balance 9928.099998
# day 28: buy 1 unit at price 8.810000, total balance 9919.289998
# day 29, sell 1 unit at price 8.730000, investment -5.365863 %, total balance 9928.019998,
# day 30: buy 1 unit at price 8.785000, total balance 9919.234998
# day 31: buy 1 unit at price 8.805000, total balance 9910.429997
# day 32, sell 1 unit at price 8.795000, investment -5.175197 %, total balance 9919.224998,
# day 33, sell 1 unit at price 8.820000, investment -3.342469 %, total balance 9928.044997,
# day 34: buy 1 unit at price 8.835000, total balance 9919.209997
# day 35, sell 1 unit at price 8.900000, investment -1.166024 %, total balance 9928.109997,
# day 36, sell 1 unit at price 8.980000, investment 1.183093 %, total balance 9937.089996,
# day 37: buy 1 unit at price 8.840000, total balance 9928.249996
# day 38, sell 1 unit at price 8.760000, investment 0.228838 %, total balance 9937.009996,
# day 39, sell 1 unit at price 8.830000, investment 3.214490 %, total balance 9945.839996,
# day 40, sell 1 unit at price 8.750000, investment 0.806448 %, total balance 9954.589996,
# day 41: buy 1 unit at price 8.875000, total balance 9945.714996
# day 42: buy 1 unit at price 9.000000, total balance 9936.714996
# day 44, sell 1 unit at price 8.945000, investment 1.532341 %, total balance 9945.659996,
# day 45: buy 1 unit at price 9.015000, total balance 9936.644996
# day 46: buy 1 unit at price 9.080000, total balance 9927.564996
# day 47, sell 1 unit at price 9.205000, investment 4.780877 %, total balance 9936.769996,
# day 48: buy 1 unit at price 9.195000, total balance 9927.574996
# day 50, sell 1 unit at price 9.150000, investment 3.918220 %, total balance 9936.724996,
# day 51, sell 1 unit at price 9.150000, investment 3.565360 %, total balance 9945.874995,
# day 52, sell 1 unit at price 8.990000, investment 1.696828 %, total balance 9954.864995,
# day 53, sell 1 unit at price 9.105000, investment 2.591544 %, total balance 9963.969995,
# day 54, sell 1 unit at price 9.020000, investment 0.222227 %, total balance 9972.989995,
# day 55, sell 1 unit at price 8.845000, investment -1.885747 %, total balance 9981.834995,
# day 56: buy 1 unit at price 8.865000, total balance 9972.969995
# day 57: buy 1 unit at price 8.985000, total balance 9963.984996
# day 58, sell 1 unit at price 8.860000, investment -2.422910 %, total balance 9972.844995,
# day 59, sell 1 unit at price 8.845000, investment -3.806410 %, total balance 9981.689996,
# day 60: buy 1 unit at price 8.925000, total balance 9972.764996
# day 61, sell 1 unit at price 8.775000, investment -1.015230 %, total balance 9981.539995,
# day 62: buy 1 unit at price 8.840000, total balance 9972.699995
# day 63: buy 1 unit at price 8.915000, total balance 9963.784995
# day 64, sell 1 unit at price 8.935000, investment -0.556475 %, total balance 9972.719995,
# day 65, sell 1 unit at price 8.745000, investment -2.016810 %, total balance 9981.464995,
# day 66, sell 1 unit at price 8.630000, investment -2.375566 %, total balance 9990.094995,
# day 67: buy 1 unit at price 8.660000, total balance 9981.434996
# day 68, sell 1 unit at price 8.675000, investment -2.692089 %, total balance 9990.109996,
# day 69, sell 1 unit at price 9.005000, investment 3.983837 %, total balance 9999.114996,
# day 72: buy 1 unit at price 8.415000, total balance 9990.699996
# day 73, sell 1 unit at price 8.465000, investment 0.594179 %, total balance 9999.164996,
# day 74: buy 1 unit at price 8.585000, total balance 9990.579996
# day 75, sell 1 unit at price 8.685000, investment 1.164827 %, total balance 9999.264997,
# day 77: buy 1 unit at price 8.545000, total balance 9990.719996
# day 78: buy 1 unit at price 8.605000, total balance 9982.114997
# day 79, sell 1 unit at price 8.730000, investment 2.165003 %, total balance 9990.844996,
# day 80, sell 1 unit at price 8.810000, investment 2.382346 %, total balance 9999.654997,
# day 84: buy 1 unit at price 8.840000, total balance 9990.814997
# day 85, sell 1 unit at price 8.830000, investment -0.113125 %, total balance 9999.644997,
# day 86: buy 1 unit at price 8.720000, total balance 9990.924996
# day 87, sell 1 unit at price 8.660000, investment -0.688078 %, total balance 9999.584996,
# day 88: buy 1 unit at price 8.735000, total balance 9990.849997
# day 89, sell 1 unit at price 8.725000, investment -0.114474 %, total balance 9999.574997,
# day 90: buy 1 unit at price 8.780000, total balance 9990.794997
# day 91, sell 1 unit at price 8.825000, investment 0.512529 %, total balance 9999.619997,
# day 96: buy 1 unit at price 8.695000, total balance 9990.924997
# day 97: buy 1 unit at price 8.760000, total balance 9982.164997
# day 98, sell 1 unit at price 8.905000, investment 2.415182 %, total balance 9991.069997,
# day 99: buy 1 unit at price 9.120000, total balance 9981.949997
# day 100: buy 1 unit at price 9.160000, total balance 9972.789997
# day 101, sell 1 unit at price 9.000000, investment 2.739723 %, total balance 9981.789997,
# day 102: buy 1 unit at price 9.070000, total balance 9972.719997
# day 103: buy 1 unit at price 9.095000, total balance 9963.624997
# day 104, sell 1 unit at price 9.145000, investment 0.274129 %, total balance 9972.769998,
# day 106: buy 1 unit at price 9.180000, total balance 9963.589997
# day 107: buy 1 unit at price 9.370000, total balance 9954.219997
# day 108: buy 1 unit at price 9.285000, total balance 9944.934998
# day 109: buy 1 unit at price 9.365000, total balance 9935.569998
# day 110: buy 1 unit at price 9.375000, total balance 9926.194998
# day 111, sell 1 unit at price 9.500000, investment 3.711792 %, total balance 9935.694998,
# day 113: buy 1 unit at price 9.080000, total balance 9926.614998
# day 114: buy 1 unit at price 9.365000, total balance 9917.249998
# day 115, sell 1 unit at price 9.220000, investment 1.653810 %, total balance 9926.469998,
# day 116, sell 1 unit at price 9.100000, investment 0.054977 %, total balance 9935.569999,
# day 117: buy 1 unit at price 9.080000, total balance 9926.489999
# day 118, sell 1 unit at price 9.115000, investment -0.708067 %, total balance 9935.604999,
# day 119: buy 1 unit at price 9.360000, total balance 9926.244999
# day 120: buy 1 unit at price 9.320000, total balance 9916.924999
# day 121: buy 1 unit at price 9.360000, total balance 9907.565000
# day 122: buy 1 unit at price 9.330000, total balance 9898.235000
# day 123, sell 1 unit at price 9.500000, investment 1.387408 %, total balance 9907.735000,
# day 124, sell 1 unit at price 9.715000, investment 4.631129 %, total balance 9917.450000,
# day 125, sell 1 unit at price 9.805000, investment 4.698351 %, total balance 9927.255000,
# day 126: buy 1 unit at price 9.845000, total balance 9917.410000
# day 127: buy 1 unit at price 9.670000, total balance 9907.740000
# day 128, sell 1 unit at price 9.575000, investment 2.133331 %, total balance 9917.315000,
# day 129: buy 1 unit at price 9.700000, total balance 9907.615000
# day 130, sell 1 unit at price 9.890000, investment 8.920710 %, total balance 9917.505000,
# day 131: buy 1 unit at price 9.880000, total balance 9907.625000
# day 132: buy 1 unit at price 10.005000, total balance 9897.620000
# day 133: buy 1 unit at price 9.710000, total balance 9887.910000
# day 134: buy 1 unit at price 9.800000, total balance 9878.110000
# day 135: buy 1 unit at price 9.950000, total balance 9868.160000
# day 136, sell 1 unit at price 9.840000, investment 5.072081 %, total balance 9878.000000,
# day 137, sell 1 unit at price 9.855000, investment 8.535238 %, total balance 9887.855000,
# day 139: buy 1 unit at price 10.075000, total balance 9877.780000
# day 140: buy 1 unit at price 10.195000, total balance 9867.585000
# day 141: buy 1 unit at price 10.290000, total balance 9857.295000
# day 142, sell 1 unit at price 10.270000, investment 9.722231 %, total balance 9867.565001,
# day 143: buy 1 unit at price 10.170000, total balance 9857.395000
# day 144, sell 1 unit at price 9.970000, investment 6.974255 %, total balance 9867.365001,
# day 145: buy 1 unit at price 10.090000, total balance 9857.275001
# day 146, sell 1 unit at price 10.175000, investment 8.707271 %, total balance 9867.450001,
# day 147: buy 1 unit at price 10.190000, total balance 9857.260001
# day 148, sell 1 unit at price 10.270000, investment 10.075033 %, total balance 9867.530002,
# day 149: buy 1 unit at price 10.295000, total balance 9857.235002
# day 150, sell 1 unit at price 10.300000, investment 4.621634 %, total balance 9867.535002,
# day 151: buy 1 unit at price 10.375000, total balance 9857.160002
# day 152: buy 1 unit at price 10.450000, total balance 9846.710002
# day 153: buy 1 unit at price 10.400000, total balance 9836.310002
# day 154: buy 1 unit at price 10.410000, total balance 9825.900002
# day 155, sell 1 unit at price 10.450000, investment 8.066181 %, total balance 9836.350002,
# day 156: buy 1 unit at price 10.435000, total balance 9825.915002
# day 157, sell 1 unit at price 10.495000, investment 8.195877 %, total balance 9836.410002,
# day 158: buy 1 unit at price 10.540000, total balance 9825.870002
# day 159, sell 1 unit at price 10.250000, investment 3.744938 %, total balance 9836.120002,
# day 160, sell 1 unit at price 10.245000, investment 2.398798 %, total balance 9846.365002,
# day 161, sell 1 unit at price 10.250000, investment 5.561277 %, total balance 9856.615002,
# day 162, sell 1 unit at price 10.190000, investment 3.979586 %, total balance 9866.805001,
# day 163: buy 1 unit at price 10.150000, total balance 9856.655002
# day 164, sell 1 unit at price 10.270000, investment 3.216087 %, total balance 9866.925002,
# day 165, sell 1 unit at price 10.325000, investment 2.481390 %, total balance 9877.250002,
# day 166: buy 1 unit at price 10.175000, total balance 9867.075002
# day 167: buy 1 unit at price 10.230000, total balance 9856.845002
# day 168: buy 1 unit at price 10.385000, total balance 9846.460002
# day 169, sell 1 unit at price 10.380000, investment 1.814619 %, total balance 9856.840002,
# day 170: buy 1 unit at price 10.355000, total balance 9846.485003
# day 171, sell 1 unit at price 10.400000, investment 1.068996 %, total balance 9856.885002,
# day 172, sell 1 unit at price 10.425000, investment 2.507376 %, total balance 9867.310002,
# day 173: buy 1 unit at price 10.350000, total balance 9856.960002
# day 174, sell 1 unit at price 10.485000, investment 3.914762 %, total balance 9867.445002,
# day 175: buy 1 unit at price 10.550000, total balance 9856.895001
# day 176, sell 1 unit at price 10.610000, investment 4.121689 %, total balance 9867.505001,
# day 178, sell 1 unit at price 10.250000, investment -0.437106 %, total balance 9877.755001,
# day 179: buy 1 unit at price 10.140000, total balance 9867.615001
# day 180, sell 1 unit at price 10.010000, investment -3.518070 %, total balance 9877.625001,
# day 181, sell 1 unit at price 10.070000, investment -3.636365 %, total balance 9887.695001,
# day 182, sell 1 unit at price 9.930000, investment -4.519224 %, total balance 9897.625001,
# day 184: buy 1 unit at price 10.150000, total balance 9887.475001
# day 185: buy 1 unit at price 10.060000, total balance 9877.415001
# day 186, sell 1 unit at price 10.100000, investment -2.977901 %, total balance 9887.515001,
# day 187, sell 1 unit at price 10.170000, investment -2.539534 %, total balance 9897.685001,
# day 188, sell 1 unit at price 10.370000, investment -1.612904 %, total balance 9908.055001,
# day 189: buy 1 unit at price 10.270000, total balance 9897.785001
# day 190, sell 1 unit at price 10.040000, investment -1.083741 %, total balance 9907.825001,
# day 191: buy 1 unit at price 10.000000, total balance 9897.825001
# day 192, sell 1 unit at price 10.170000, investment -0.049141 %, total balance 9907.995001,
# day 193, sell 1 unit at price 10.030000, investment -1.955032 %, total balance 9918.025001,
# day 194, sell 1 unit at price 10.020000, investment -3.514682 %, total balance 9928.045001,
# day 195, sell 1 unit at price 9.740000, investment -5.939158 %, total balance 9937.785001,
# day 197: buy 1 unit at price 9.740000, total balance 9928.045001
# day 198, sell 1 unit at price 9.910000, investment -4.251213 %, total balance 9937.955001,
# day 199, sell 1 unit at price 10.220000, investment -3.127961 %, total balance 9948.175001,
# day 200, sell 1 unit at price 9.800000, investment -3.353059 %, total balance 9957.975001,
# day 202: buy 1 unit at price 9.580000, total balance 9948.395001
# day 203, sell 1 unit at price 9.480000, investment -6.600986 %, total balance 9957.875001,
# day 204, sell 1 unit at price 9.400000, investment -6.560644 %, total balance 9967.275001,
# day 205, sell 1 unit at price 9.060000, investment -11.781889 %, total balance 9976.335001,
# day 206, sell 1 unit at price 9.110000, investment -8.900003 %, total balance 9985.445001,
# day 208, sell 1 unit at price 8.970000, investment -7.905539 %, total balance 9994.415001,
# day 209: buy 1 unit at price 9.190000, total balance 9985.225001
# day 210, sell 1 unit at price 9.470000, investment -1.148222 %, total balance 9994.695002,
# day 212: buy 1 unit at price 9.250000, total balance 9985.445002
# day 213, sell 1 unit at price 9.400000, investment 2.285093 %, total balance 9994.845001,
# day 214, sell 1 unit at price 9.480000, investment 2.486482 %, total balance 10004.325001,
# day 219: buy 1 unit at price 9.400000, total balance 9994.925001
# day 220, sell 1 unit at price 9.250000, investment -1.595741 %, total balance 10004.175001,
# day 225: buy 1 unit at price 9.070000, total balance 9995.105001
# day 226, sell 1 unit at price 9.090000, investment 0.220512 %, total balance 10004.195002,
# day 230: buy 1 unit at price 9.680000, total balance 9994.515001
# day 232: buy 1 unit at price 9.900000, total balance 9984.615002
# day 233, sell 1 unit at price 9.850000, investment 1.756199 %, total balance 9994.465002,
# day 234: buy 1 unit at price 9.830000, total balance 9984.635002
# day 235, sell 1 unit at price 9.690000, investment -2.121213 %, total balance 9994.325002,
# day 236: buy 1 unit at price 9.570000, total balance 9984.755002
# day 237: buy 1 unit at price 9.690000, total balance 9975.065002
# day 238, sell 1 unit at price 9.660000, investment -1.729401 %, total balance 9984.725002,
# day 239, sell 1 unit at price 9.870000, investment 3.134798 %, total balance 9994.595002,
# day 240: buy 1 unit at price 9.890000, total balance 9984.705002
# day 241, sell 1 unit at price 9.600000, investment -0.928784 %, total balance 9994.305002,
# day 242: buy 1 unit at price 9.540000, total balance 9984.765002
# day 243, sell 1 unit at price 9.430000, investment -4.651163 %, total balance 9994.195003,
# day 244: buy 1 unit at price 9.280000, total balance 9984.915003
# day 245, sell 1 unit at price 9.100000, investment -4.612155 %, total balance 9994.015003,
# day 247: buy 1 unit at price 9.380000, total balance 9984.635003
# day 248: buy 1 unit at price 9.450000, total balance 9975.185003
# day 249: buy 1 unit at price 9.430000, total balance 9965.755003
# day 250: buy 1 unit at price 9.520000, total balance 9956.235003
# day 251, sell 1 unit at price 9.610000, investment 3.556034 %, total balance 9965.845002,
# day 252, sell 1 unit at price 9.470000, investment 0.959490 %, total balance 9975.315002,
# day 253, sell 1 unit at price 9.630000, investment 1.904765 %, total balance 9984.945003,
# day 254, sell 1 unit at price 9.710000, investment 2.969244 %, total balance 9994.655003,
# day 255, sell 1 unit at price 9.750000, investment 2.415961 %, total balance 10004.405003,
# day 256: buy 1 unit at price 9.870000, total balance 9994.535003
# day 257: buy 1 unit at price 9.880000, total balance 9984.655003
# day 258: buy 1 unit at price 10.410000, total balance 9974.245003
# day 259, sell 1 unit at price 10.370000, investment 5.065856 %, total balance 9984.615003,
# day 260: buy 1 unit at price 10.490000, total balance 9974.125003
# day 261: buy 1 unit at price 10.610000, total balance 9963.515003
# day 262, sell 1 unit at price 10.580000, investment 7.085018 %, total balance 9974.095003,
# day 263, sell 1 unit at price 10.670000, investment 2.497601 %, total balance 9984.765003,
# day 264, sell 1 unit at price 10.530000, investment 0.381315 %, total balance 9995.295003,
# day 265, sell 1 unit at price 10.530000, investment -0.754005 %, total balance 10005.825003,
# day 269: buy 1 unit at price 10.480000, total balance 9995.345003
# day 270: buy 1 unit at price 10.590000, total balance 9984.755003
# day 271: buy 1 unit at price 10.800000, total balance 9973.955003
# day 272: buy 1 unit at price 10.900000, total balance 9963.055003
# day 273: buy 1 unit at price 10.870000, total balance 9952.185003
# day 274: buy 1 unit at price 10.840000, total balance 9941.345003
# day 275: buy 1 unit at price 10.900000, total balance 9930.445004
# day 276: buy 1 unit at price 10.850000, total balance 9919.595003
# day 277, sell 1 unit at price 10.860000, investment 3.625955 %, total balance 9930.455003,
# day 278: buy 1 unit at price 10.820000, total balance 9919.635003
# day 279: buy 1 unit at price 10.770000, total balance 9908.865003
# day 280: buy 1 unit at price 10.800000, total balance 9898.065002
# day 281: buy 1 unit at price 10.760000, total balance 9887.305002
# day 282: buy 1 unit at price 10.760000, total balance 9876.545002
# day 283, sell 1 unit at price 10.550000, investment -0.377714 %, total balance 9887.095002,
# day 284: buy 1 unit at price 10.700000, total balance 9876.395002
# day 285: buy 1 unit at price 10.550000, total balance 9865.845002
# day 286: buy 1 unit at price 10.630000, total balance 9855.215002
# day 287: buy 1 unit at price 10.810000, total balance 9844.405002
# day 288: buy 1 unit at price 10.730000, total balance 9833.675002
# day 289: buy 1 unit at price 10.700000, total balance 9822.975002
# day 290: buy 1 unit at price 10.720000, total balance 9812.255002
# day 291: buy 1 unit at price 10.840000, total balance 9801.415002
# day 292, sell 1 unit at price 10.720000, investment -0.740740 %, total balance 9812.135002,
# day 293, sell 1 unit at price 10.770000, investment -1.192653 %, total balance 9822.905003,
# day 294: buy 1 unit at price 10.710000, total balance 9812.195003
# day 295, sell 1 unit at price 10.490000, investment -3.495861 %, total balance 9822.685002,
# day 296, sell 1 unit at price 10.470000, investment -3.413283 %, total balance 9833.155003,
# day 297: buy 1 unit at price 10.550000, total balance 9822.605002
# day 298, sell 1 unit at price 10.520000, investment -3.486231 %, total balance 9833.125003,
# day 299: buy 1 unit at price 10.550000, total balance 9822.575003
# day 300: buy 1 unit at price 10.600000, total balance 9811.975002
# day 302: buy 1 unit at price 10.720000, total balance 9801.255002
# day 303, sell 1 unit at price 10.900000, investment 0.460822 %, total balance 9812.155002,
# day 304, sell 1 unit at price 10.940000, investment 1.109056 %, total balance 9823.095001,
# day 305, sell 1 unit at price 11.060000, investment 2.692664 %, total balance 9834.155002,
# day 306: buy 1 unit at price 10.880000, total balance 9823.275002
# day 307, sell 1 unit at price 10.820000, investment 0.185181 %, total balance 9834.095001,
# day 308: buy 1 unit at price 10.820000, total balance 9823.275002
# day 309, sell 1 unit at price 10.730000, investment -0.278817 %, total balance 9834.005001,
# day 310: buy 1 unit at price 10.880000, total balance 9823.125001
# day 312: buy 1 unit at price 11.090000, total balance 9812.035001
# day 313: buy 1 unit at price 11.180000, total balance 9800.855000
# day 314: buy 1 unit at price 11.200000, total balance 9789.655001
# day 315, sell 1 unit at price 11.070000, investment 2.881036 %, total balance 9800.725000,
# day 316, sell 1 unit at price 11.320000, investment 5.794392 %, total balance 9812.045000,
# day 317: buy 1 unit at price 11.310000, total balance 9800.735000
# day 319: buy 1 unit at price 11.080000, total balance 9789.655000
# day 321, sell 1 unit at price 10.550000, investment 0.000000 %, total balance 9800.205000,
# day 322, sell 1 unit at price 10.570000, investment -0.564444 %, total balance 9810.775000,
# day 323, sell 1 unit at price 10.370000, investment -4.070310 %, total balance 9821.145000,
# day 324, sell 1 unit at price 10.410000, investment -2.982290 %, total balance 9831.554999,
# day 325: buy 1 unit at price 10.390000, total balance 9821.164999
# day 327: buy 1 unit at price 10.530000, total balance 9810.634999
# day 328, sell 1 unit at price 10.580000, investment -1.121494 %, total balance 9821.214999,
# day 329: buy 1 unit at price 10.520000, total balance 9810.694999
# day 330, sell 1 unit at price 10.650000, investment -0.652991 %, total balance 9821.344998,
# day 331, sell 1 unit at price 10.750000, investment -0.830260 %, total balance 9832.094998,
# day 332, sell 1 unit at price 10.760000, investment 0.466855 %, total balance 9842.854999,
# day 333, sell 1 unit at price 10.770000, investment 2.085311 %, total balance 9853.624999,
# day 334, sell 1 unit at price 10.570000, investment 0.189569 %, total balance 9864.194999,
# day 335, sell 1 unit at price 10.330000, investment -2.547174 %, total balance 9874.524999,
# day 336, sell 1 unit at price 10.450000, investment -2.518661 %, total balance 9884.974998,
# day 338, sell 1 unit at price 10.390000, investment -4.503674 %, total balance 9895.364999,
# day 340, sell 1 unit at price 10.260000, investment -5.175596 %, total balance 9905.624999,
# day 341: buy 1 unit at price 10.110000, total balance 9895.514999
# day 342, sell 1 unit at price 10.210000, investment -6.158089 %, total balance 9905.724999,
# day 343: buy 1 unit at price 10.390000, total balance 9895.334999
# day 344, sell 1 unit at price 10.510000, investment -5.229936 %, total balance 9905.844999,
# day 345, sell 1 unit at price 10.170000, investment -9.033991 %, total balance 9916.014999,
# day 346, sell 1 unit at price 10.200000, investment -8.928572 %, total balance 9926.214999,
# day 347, sell 1 unit at price 10.180000, investment -9.991159 %, total balance 9936.395000,
# day 348, sell 1 unit at price 10.220000, investment -7.761730 %, total balance 9946.615000,
# day 349, sell 1 unit at price 10.160000, investment -2.213672 %, total balance 9956.775000,
# day 350, sell 1 unit at price 10.230000, investment -2.849005 %, total balance 9967.004999,
# day 352, sell 1 unit at price 10.270000, investment -2.376426 %, total balance 9977.275000,
# day 353: buy 1 unit at price 10.570000, total balance 9966.705000
# day 354, sell 1 unit at price 10.470000, investment 3.560837 %, total balance 9977.175000,
# day 355, sell 1 unit at price 10.450000, investment 0.577473 %, total balance 9987.625000,
# day 356, sell 1 unit at price 10.580000, investment 0.094610 %, total balance 9998.205000,
# day 357: buy 1 unit at price 10.440000, total balance 9987.765000
# day 358, sell 1 unit at price 10.530000, investment 0.862070 %, total balance 9998.295000,
# day 359: buy 1 unit at price 10.630000, total balance 9987.665000
# day 360, sell 1 unit at price 10.780000, investment 1.411097 %, total balance 9998.445000,
# day 363: buy 1 unit at price 10.620000, total balance 9987.825000
# day 364, sell 1 unit at price 10.600000, investment -0.188319 %, total balance 9998.425000,
# day 367: buy 1 unit at price 10.600000, total balance 9987.825000
# day 369: buy 1 unit at price 10.720000, total balance 9977.105000
# day 370: buy 1 unit at price 10.680000, total balance 9966.424999
# day 371: buy 1 unit at price 10.650000, total balance 9955.775000
# day 372, sell 1 unit at price 10.660000, investment 0.566033 %, total balance 9966.434999,
# day 373, sell 1 unit at price 10.620000, investment -0.932839 %, total balance 9977.054999,
# day 374: buy 1 unit at price 10.700000, total balance 9966.355000
# day 375: buy 1 unit at price 10.700000, total balance 9955.655000
# day 376, sell 1 unit at price 10.760000, investment 0.749063 %, total balance 9966.415000,
# day 377: buy 1 unit at price 10.740000, total balance 9955.675000
# day 378, sell 1 unit at price 10.690000, investment 0.375587 %, total balance 9966.365000,
# day 379: buy 1 unit at price 10.560000, total balance 9955.804999
# day 380, sell 1 unit at price 10.420000, investment -2.616820 %, total balance 9966.224999,
# day 381: buy 1 unit at price 10.480000, total balance 9955.745000
# day 382, sell 1 unit at price 10.720000, investment 0.186920 %, total balance 9966.465000,
# day 383: buy 1 unit at price 11.400000, total balance 9955.065001
# day 384: buy 1 unit at price 11.500000, total balance 9943.565001
# day 385: buy 1 unit at price 11.530000, total balance 9932.035001
# day 386: buy 1 unit at price 11.490000, total balance 9920.545001
# day 387: buy 1 unit at price 11.550000, total balance 9908.995001
# day 388, sell 1 unit at price 11.390000, investment 6.052147 %, total balance 9920.385001,
# day 389, sell 1 unit at price 11.460000, investment 8.522723 %, total balance 9931.845001,
# day 390: buy 1 unit at price 11.490000, total balance 9920.355001
# day 392: buy 1 unit at price 11.520000, total balance 9908.835001
# day 393: buy 1 unit at price 11.480000, total balance 9897.355001
# day 394: buy 1 unit at price 11.510000, total balance 9885.845001
# day 396: buy 1 unit at price 11.320000, total balance 9874.525002
# day 397: buy 1 unit at price 11.260000, total balance 9863.265001
# day 398: buy 1 unit at price 11.080000, total balance 9852.185001
# day 399: buy 1 unit at price 10.900000, total balance 9841.285002
# day 400: buy 1 unit at price 11.000000, total balance 9830.285002
# day 401, sell 1 unit at price 11.160000, investment 6.488553 %, total balance 9841.445002,
# day 402, sell 1 unit at price 11.250000, investment -1.315786 %, total balance 9852.695002,
# day 403: buy 1 unit at price 11.130000, total balance 9841.565001
# day 405: buy 1 unit at price 11.060000, total balance 9830.505001
# day 406, sell 1 unit at price 10.790000, investment -6.173913 %, total balance 9841.295001,
# day 407, sell 1 unit at price 10.930000, investment -5.203811 %, total balance 9852.225001,
# day 408, sell 1 unit at price 11.070000, investment -3.655353 %, total balance 9863.295001,
# day 409, sell 1 unit at price 11.130000, investment -3.636364 %, total balance 9874.425001,
# day 410: buy 1 unit at price 11.330000, total balance 9863.095001
# day 411: buy 1 unit at price 11.300000, total balance 9851.795001
# day 412, sell 1 unit at price 11.210000, investment -2.436899 %, total balance 9863.005001,
# day 413, sell 1 unit at price 11.110000, investment -3.559035 %, total balance 9874.115001,
# day 414, sell 1 unit at price 11.130000, investment -3.048776 %, total balance 9885.245001,
# day 415, sell 1 unit at price 11.150000, investment -3.127720 %, total balance 9896.395000,
# day 416, sell 1 unit at price 11.200000, investment -1.060070 %, total balance 9907.595000,
# day 417: buy 1 unit at price 11.390000, total balance 9896.205000
# day 418: buy 1 unit at price 11.490000, total balance 9884.715000
# day 419, sell 1 unit at price 11.280000, investment 0.177615 %, total balance 9895.995000,
# day 420: buy 1 unit at price 11.680000, total balance 9884.315000
# day 421: buy 1 unit at price 12.070000, total balance 9872.245000
# day 422, sell 1 unit at price 11.810000, investment 6.588452 %, total balance 9884.055000,
# day 423: buy 1 unit at price 11.640000, total balance 9872.415000
# day 424: buy 1 unit at price 11.620000, total balance 9860.795000
# day 425, sell 1 unit at price 11.580000, investment 6.238535 %, total balance 9872.375000,
# day 426, sell 1 unit at price 11.680000, investment 6.181821 %, total balance 9884.055000,
# day 427, sell 1 unit at price 11.770000, investment 5.750228 %, total balance 9895.825001,
# day 428: buy 1 unit at price 11.760000, total balance 9884.065001
# day 431: buy 1 unit at price 11.600000, total balance 9872.465000
# day 432, sell 1 unit at price 11.350000, investment 2.622061 %, total balance 9883.815001,
# day 433, sell 1 unit at price 11.000000, investment -2.912621 %, total balance 9894.815001,
# day 434, sell 1 unit at price 11.040000, investment -2.300887 %, total balance 9905.855000,
# day 435: buy 1 unit at price 11.060000, total balance 9894.795000
# day 436: buy 1 unit at price 11.130000, total balance 9883.665000
# day 437: buy 1 unit at price 11.210000, total balance 9872.455000
# day 438: buy 1 unit at price 11.370000, total balance 9861.085000
# day 439, sell 1 unit at price 11.040000, investment -3.072874 %, total balance 9872.125000,
# day 440, sell 1 unit at price 11.080000, investment -3.568319 %, total balance 9883.205000,
# day 441: buy 1 unit at price 11.160000, total balance 9872.045000
# day 442, sell 1 unit at price 11.220000, investment -3.938356 %, total balance 9883.265000,
# day 443, sell 1 unit at price 11.290000, investment -6.462301 %, total balance 9894.555000,
# day 444, sell 1 unit at price 11.120000, investment -4.467358 %, total balance 9905.675000,
# day 445: buy 1 unit at price 11.160000, total balance 9894.515000
# day 446, sell 1 unit at price 11.180000, investment -3.786571 %, total balance 9905.695001,
# day 447, sell 1 unit at price 10.970000, investment -6.717687 %, total balance 9916.665001,
# day 448, sell 1 unit at price 10.620000, investment -8.448280 %, total balance 9927.285001,
# day 449, sell 1 unit at price 10.670000, investment -3.526224 %, total balance 9937.955001,
# day 451: buy 1 unit at price 10.590000, total balance 9927.365001
# day 452: buy 1 unit at price 10.570000, total balance 9916.795001
# day 453, sell 1 unit at price 9.290000, investment -16.531897 %, total balance 9926.085001,
# day 454, sell 1 unit at price 9.010000, investment -19.625333 %, total balance 9935.095001,
# day 455, sell 1 unit at price 9.040000, investment -20.492524 %, total balance 9944.135001,
# day 456, sell 1 unit at price 8.930000, investment -19.982075 %, total balance 9953.065001,
# day 457: buy 1 unit at price 9.200000, total balance 9943.865002
# day 458: buy 1 unit at price 9.160000, total balance 9934.705002
# day 460: buy 1 unit at price 9.320000, total balance 9925.385002
# day 461, sell 1 unit at price 9.590000, investment -14.068098 %, total balance 9934.975002,
# day 462, sell 1 unit at price 9.520000, investment -10.103869 %, total balance 9944.495003,
# day 463, sell 1 unit at price 9.760000, investment -7.663193 %, total balance 9954.255003,
# day 465, sell 1 unit at price 9.880000, investment 7.391308 %, total balance 9964.135003,
# day 466: buy 1 unit at price 10.020000, total balance 9954.115003
# day 467, sell 1 unit at price 9.680000, investment 5.676861 %, total balance 9963.795003,
# day 468, sell 1 unit at price 9.790000, investment 5.042921 %, total balance 9973.585003,
# day 469, sell 1 unit at price 9.750000, investment -2.694615 %, total balance 9983.335003,
# day 471: buy 1 unit at price 9.870000, total balance 9973.465003
# day 472: buy 1 unit at price 9.860000, total balance 9963.605003
# day 473: buy 1 unit at price 9.860000, total balance 9953.745004
# day 474, sell 1 unit at price 9.830000, investment -0.405268 %, total balance 9963.575004,
# day 475, sell 1 unit at price 9.920000, investment 0.608524 %, total balance 9973.495004,
# day 476: buy 1 unit at price 9.870000, total balance 9963.625004
# day 477, sell 1 unit at price 9.600000, investment -2.636910 %, total balance 9973.225004,
# day 478: buy 1 unit at price 9.870000, total balance 9963.355004
# day 479, sell 1 unit at price 9.650000, investment -2.228979 %, total balance 9973.005004,
# day 480, sell 1 unit at price 9.780000, investment -0.911856 %, total balance 9982.785004,
# day 483: buy 1 unit at price 9.670000, total balance 9973.115004
# day 484: buy 1 unit at price 9.860000, total balance 9963.255004
# day 485: buy 1 unit at price 9.890000, total balance 9953.365004
# day 486, sell 1 unit at price 9.940000, investment 2.792135 %, total balance 9963.305003,
# day 487: buy 1 unit at price 9.940000, total balance 9953.365004
# day 488, sell 1 unit at price 10.040000, investment 1.825561 %, total balance 9963.405004,
# day 489: buy 1 unit at price 10.070000, total balance 9953.335004
# day 490, sell 1 unit at price 10.030000, investment 1.415565 %, total balance 9963.365004,
# day 491: buy 1 unit at price 10.080000, total balance 9953.285004
# day 492, sell 1 unit at price 10.130000, investment 1.911474 %, total balance 9963.415004,
# day 493: buy 1 unit at price 10.290000, total balance 9953.125004
# day 494: buy 1 unit at price 10.330000, total balance 9942.795004
# day 495: buy 1 unit at price 10.270000, total balance 9932.525003
# day 496, sell 1 unit at price 10.290000, investment 2.184710 %, total balance 9942.815003,
# day 497, sell 1 unit at price 10.290000, investment 2.083334 %, total balance 9953.105003,
# day 498, sell 1 unit at price 10.240000, investment -0.485911 %, total balance 9963.345003,
# day 499, sell 1 unit at price 10.170000, investment -1.548885 %, total balance 9973.515003,
# day 500, sell 1 unit at price 10.260000, investment -0.097373 %, total balance 9983.775003,
# day 501: buy 1 unit at price 10.160000, total balance 9973.615004
# day 502: buy 1 unit at price 10.320000, total balance 9963.295004
# day 503: buy 1 unit at price 10.290000, total balance 9953.005004
# day 504, sell 1 unit at price 10.310000, investment 1.476384 %, total balance 9963.315004,
# day 506, sell 1 unit at price 10.100000, investment -2.131776 %, total balance 9973.415005,
# day 507: buy 1 unit at price 10.090000, total balance 9963.325005
# day 508: buy 1 unit at price 10.480000, total balance 9952.845005
# day 509: buy 1 unit at price 10.650000, total balance 9942.195005
# day 510, sell 1 unit at price 10.880000, investment 5.733724 %, total balance 9953.075006,
# day 511: buy 1 unit at price 10.860000, total balance 9942.215006
# day 512: buy 1 unit at price 10.850000, total balance 9931.365005
# day 513: buy 1 unit at price 10.850000, total balance 9920.515005
# day 514, sell 1 unit at price 10.880000, investment 7.829534 %, total balance 9931.395005,
# day 515, sell 1 unit at price 10.850000, investment 3.530543 %, total balance 9942.245006,
# day 516, sell 1 unit at price 11.040000, investment 3.661975 %, total balance 9953.285006,
# day 517: buy 1 unit at price 11.060000, total balance 9942.225005
# day 518: buy 1 unit at price 11.030000, total balance 9931.195005
# day 519: buy 1 unit at price 10.990000, total balance 9920.205006
# day 520: buy 1 unit at price 11.100000, total balance 9909.105005
# day 521: buy 1 unit at price 11.060000, total balance 9898.045005
# day 522, sell 1 unit at price 11.060000, investment 1.841628 %, total balance 9909.105005,
# day 523: buy 1 unit at price 10.960000, total balance 9898.145005
# day 524: buy 1 unit at price 10.940000, total balance 9887.205006
# day 525: buy 1 unit at price 11.100000, total balance 9876.105005
# day 526, sell 1 unit at price 11.040000, investment 1.751148 %, total balance 9887.145005,
# day 527, sell 1 unit at price 10.960000, investment 1.013822 %, total balance 9898.105005,
# day 528, sell 1 unit at price 10.850000, investment -1.898734 %, total balance 9908.955006,
# day 529: buy 1 unit at price 10.920000, total balance 9898.035006
# day 530, sell 1 unit at price 10.950000, investment -0.725294 %, total balance 9908.985005,
# day 531: buy 1 unit at price 11.220000, total balance 9897.765005
# day 532: buy 1 unit at price 11.100000, total balance 9886.665005
# day 533, sell 1 unit at price 11.010000, investment 0.181988 %, total balance 9897.675005,
# day 534: buy 1 unit at price 11.210000, total balance 9886.465005
# day 535, sell 1 unit at price 11.300000, investment 1.801800 %, total balance 9897.765005,
# day 536, sell 1 unit at price 11.360000, investment 2.712470 %, total balance 9909.125005,
# day 537: buy 1 unit at price 11.410000, total balance 9897.715005
# day 538: buy 1 unit at price 11.220000, total balance 9886.495005
# day 539, sell 1 unit at price 11.020000, investment 0.547449 %, total balance 9897.515005,
# day 540, sell 1 unit at price 11.000000, investment 0.548450 %, total balance 9908.515005,
# day 541, sell 1 unit at price 10.620000, investment -4.324329 %, total balance 9919.135005,
# day 542, sell 1 unit at price 10.070000, investment -7.783886 %, total balance 9929.205005,
# day 543, sell 1 unit at price 10.360000, investment -7.664889 %, total balance 9939.565004,
# day 544: buy 1 unit at price 10.210000, total balance 9929.355004
# day 545: buy 1 unit at price 10.470000, total balance 9918.885004
# day 546: buy 1 unit at price 10.130000, total balance 9908.755004
# day 547, sell 1 unit at price 9.780000, investment -11.891897 %, total balance 9918.535004,
# day 548, sell 1 unit at price 9.080000, investment -19.000893 %, total balance 9927.615004,
# day 549, sell 1 unit at price 9.190000, investment -19.456620 %, total balance 9936.805003,
# day 550, sell 1 unit at price 8.900000, investment -20.677367 %, total balance 9945.705003,
# day 551, sell 1 unit at price 8.050000, investment -21.155728 %, total balance 9953.755003,
# day 552, sell 1 unit at price 8.380000, investment -19.961797 %, total balance 9962.135003,
# day 553, sell 1 unit at price 7.370000, investment -27.245806 %, total balance 9969.505003,
# day 559: buy 1 unit at price 7.740000, total balance 9961.765003
# day 560, sell 1 unit at price 8.190000, investment 5.813951 %, total balance 9969.955003,
# day 561: buy 1 unit at price 9.100000, total balance 9960.855002
# day 562, sell 1 unit at price 8.510000, investment -6.483518 %, total balance 9969.365003,
# day 567: buy 1 unit at price 7.560000, total balance 9961.805003
# day 568, sell 1 unit at price 8.250000, investment 9.126985 %, total balance 9970.055003,
# day 569: buy 1 unit at price 8.380000, total balance 9961.675003
# day 570: buy 1 unit at price 8.480000, total balance 9953.195003
# day 571: buy 1 unit at price 8.520000, total balance 9944.675003
# day 572, sell 1 unit at price 8.500000, investment 1.431980 %, total balance 9953.175003,
# day 574, sell 1 unit at price 8.330000, investment -1.768864 %, total balance 9961.505002,
# day 575, sell 1 unit at price 8.220000, investment -3.521129 %, total balance 9969.725003,
# day 576: buy 1 unit at price 8.580000, total balance 9961.145003
# day 577, sell 1 unit at price 8.510000, investment -0.815847 %, total balance 9969.655003,
# day 580: buy 1 unit at price 8.790000, total balance 9960.865003
# day 581: buy 1 unit at price 8.760000, total balance 9952.105003
# day 582: buy 1 unit at price 8.930000, total balance 9943.175003
# day 583: buy 1 unit at price 8.790000, total balance 9934.385003
# day 584, sell 1 unit at price 9.490000, investment 7.963593 %, total balance 9943.875002,
# day 585: buy 1 unit at price 9.230000, total balance 9934.645003
# day 586, sell 1 unit at price 9.060000, investment 3.424660 %, total balance 9943.705003,
# day 587, sell 1 unit at price 8.930000, investment 0.000000 %, total balance 9952.635004,
# day 588, sell 1 unit at price 8.910000, investment 1.365186 %, total balance 9961.545003,
# day 589: buy 1 unit at price 8.860000, total balance 9952.685004
# day 590, sell 1 unit at price 9.040000, investment -2.058500 %, total balance 9961.725004,
# day 591: buy 1 unit at price 9.170000, total balance 9952.555004
# day 592, sell 1 unit at price 9.000000, investment 1.580139 %, total balance 9961.555004,
# day 593, sell 1 unit at price 9.150000, investment -0.218107 %, total balance 9970.705003,
# day 596: buy 1 unit at price 8.700000, total balance 9962.005003
# day 597: buy 1 unit at price 8.960000, total balance 9953.045003
# day 598: buy 1 unit at price 8.790000, total balance 9944.255003
# day 599: buy 1 unit at price 9.000000, total balance 9935.255003
# day 600: buy 1 unit at price 8.930000, total balance 9926.325003
# day 601, sell 1 unit at price 9.050000, investment 4.022993 %, total balance 9935.375003,
# day 602, sell 1 unit at price 9.070000, investment 1.227675 %, total balance 9944.445003,
# day 603, sell 1 unit at price 9.350000, investment 6.370881 %, total balance 9953.795003,
# day 604: buy 1 unit at price 9.190000, total balance 9944.605004
# day 606, sell 1 unit at price 9.260000, investment 2.888891 %, total balance 9953.865004,
# day 607, sell 1 unit at price 9.380000, investment 5.039191 %, total balance 9963.245004,
# day 608: buy 1 unit at price 9.270000, total balance 9953.975004
# day 609, sell 1 unit at price 9.270000, investment 0.870521 %, total balance 9963.245004,
# day 610: buy 1 unit at price 9.380000, total balance 9953.865004
# day 612: buy 1 unit at price 9.330000, total balance 9944.535004
# day 613, sell 1 unit at price 9.300000, investment 0.323622 %, total balance 9953.835004,
# day 614: buy 1 unit at price 8.860000, total balance 9944.975005
# day 615, sell 1 unit at price 9.110000, investment -2.878470 %, total balance 9954.085004,
# day 616: buy 1 unit at price 9.220000, total balance 9944.865004
# day 617, sell 1 unit at price 9.120000, investment -2.250804 %, total balance 9953.985004,
# day 618: buy 1 unit at price 9.330000, total balance 9944.655004
# day 619, sell 1 unit at price 9.220000, investment 4.063212 %, total balance 9953.875004,
# day 621: buy 1 unit at price 9.150000, total balance 9944.725005
# day 622, sell 1 unit at price 9.420000, investment 2.169195 %, total balance 9954.145005,
# day 623, sell 1 unit at price 9.070000, investment -2.786712 %, total balance 9963.215004,
# day 624: buy 1 unit at price 9.290000, total balance 9953.925004
# day 625: buy 1 unit at price 9.530000, total balance 9944.395005
# day 626, sell 1 unit at price 9.570000, investment 4.590165 %, total balance 9953.965004,
# day 627: buy 1 unit at price 9.660000, total balance 9944.305005
# day 629, sell 1 unit at price 9.920000, investment 6.781487 %, total balance 9954.225005,
# day 630: buy 1 unit at price 10.110000, total balance 9944.115005
# day 632: buy 1 unit at price 10.340000, total balance 9933.775005
# day 633: buy 1 unit at price 10.230000, total balance 9923.545005
# day 634: buy 1 unit at price 10.390000, total balance 9913.155005
# day 635: buy 1 unit at price 10.470000, total balance 9902.685005
# day 636, sell 1 unit at price 10.590000, investment 11.122775 %, total balance 9913.275005,
# day 637: buy 1 unit at price 11.910000, total balance 9901.365005
# day 638, sell 1 unit at price 12.230000, investment 26.604552 %, total balance 9913.595005,
# day 639: buy 1 unit at price 12.270000, total balance 9901.325004
# day 640: buy 1 unit at price 12.580000, total balance 9888.745004
# day 641, sell 1 unit at price 12.490000, investment 23.541050 %, total balance 9901.235004,
# day 642, sell 1 unit at price 12.300000, investment 18.955513 %, total balance 9913.535004,
# day 643: buy 1 unit at price 12.240000, total balance 9901.295004
# day 644: buy 1 unit at price 12.330000, total balance 9888.965004
# day 645: buy 1 unit at price 12.670000, total balance 9876.295004
# day 646: buy 1 unit at price 12.580000, total balance 9863.715004
# day 647: buy 1 unit at price 12.850000, total balance 9850.865004
# day 648: buy 1 unit at price 12.950000, total balance 9837.915004
# day 649: buy 1 unit at price 12.850000, total balance 9825.065004
# day 650: buy 1 unit at price 12.920000, total balance 9812.145004
# day 651: buy 1 unit at price 12.640000, total balance 9799.505003
# day 652: buy 1 unit at price 12.650000, total balance 9786.855004
# day 653: buy 1 unit at price 12.830000, total balance 9774.025004
# day 655: buy 1 unit at price 12.590000, total balance 9761.435004
# day 656, sell 1 unit at price 12.630000, investment 23.460417 %, total balance 9774.065004,
# day 657: buy 1 unit at price 12.760000, total balance 9761.305004
# day 658: buy 1 unit at price 12.780000, total balance 9748.525004
# day 659, sell 1 unit at price 12.720000, investment 22.425408 %, total balance 9761.245004,
# day 660: buy 1 unit at price 12.870000, total balance 9748.375004
# day 661: buy 1 unit at price 12.980000, total balance 9735.395005
# day 662, sell 1 unit at price 12.800000, investment 22.254058 %, total balance 9748.195005,
# day 663, sell 1 unit at price 12.820000, investment 7.640637 %, total balance 9761.015005,
# day 664, sell 1 unit at price 12.600000, investment 2.689486 %, total balance 9773.615005,
# day 665: buy 1 unit at price 12.790000, total balance 9760.825005
# day 666, sell 1 unit at price 12.810000, investment 1.828303 %, total balance 9773.635005,
# day 667, sell 1 unit at price 12.880000, investment 5.228761 %, total balance 9786.515006,
# day 668: buy 1 unit at price 12.780000, total balance 9773.735006
# day 669, sell 1 unit at price 12.810000, investment 3.892948 %, total balance 9786.545006,
# day 670, sell 1 unit at price 12.600000, investment -0.552484 %, total balance 9799.145007,
# day 671, sell 1 unit at price 12.670000, investment 0.715423 %, total balance 9811.815007,
# day 672, sell 1 unit at price 12.730000, investment -0.933859 %, total balance 9824.545006,
# day 673, sell 1 unit at price 12.470000, investment -3.706560 %, total balance 9837.015007,
# day 674, sell 1 unit at price 12.440000, investment -3.190668 %, total balance 9849.455006,
# day 675: buy 1 unit at price 12.670000, total balance 9836.785006
# day 676: buy 1 unit at price 12.750000, total balance 9824.035006
# day 677, sell 1 unit at price 12.600000, investment -2.476778 %, total balance 9836.635006,
# day 678: buy 1 unit at price 12.760000, total balance 9823.875006
# day 679, sell 1 unit at price 13.240000, investment 4.746831 %, total balance 9837.115006,
# day 680: buy 1 unit at price 13.340000, total balance 9823.775006
# day 681: buy 1 unit at price 13.560000, total balance 9810.215005
# day 682: buy 1 unit at price 13.670000, total balance 9796.545005
# day 683, sell 1 unit at price 13.500000, investment 6.719371 %, total balance 9810.045005,
# day 684, sell 1 unit at price 13.610000, investment 6.079499 %, total balance 9823.655005,
# day 685: buy 1 unit at price 13.840000, total balance 9809.815005
# day 686, sell 1 unit at price 13.590000, investment 7.942812 %, total balance 9823.405005,
# day 687, sell 1 unit at price 13.050000, investment 2.272727 %, total balance 9836.455005,
# day 689: buy 1 unit at price 13.630000, total balance 9822.825005
# day 690, sell 1 unit at price 13.560000, investment 6.103292 %, total balance 9836.385005,
# day 691: buy 1 unit at price 13.810000, total balance 9822.575005
# day 692: buy 1 unit at price 13.760000, total balance 9808.815005
# day 693: buy 1 unit at price 13.670000, total balance 9795.145005
# day 694: buy 1 unit at price 14.050000, total balance 9781.095005
# day 695: buy 1 unit at price 13.890000, total balance 9767.205004
# day 696: buy 1 unit at price 14.540000, total balance 9752.665004
# day 697: buy 1 unit at price 14.800000, total balance 9737.865004
# day 698, sell 1 unit at price 15.200000, investment 18.104118 %, total balance 9753.065004,
# day 699: buy 1 unit at price 15.550000, total balance 9737.515004
# day 700, sell 1 unit at price 15.720000, investment 21.109405 %, total balance 9753.235004,
# day 701, sell 1 unit at price 16.360001, investment 27.912437 %, total balance 9769.595005,
# day 702, sell 1 unit at price 15.260000, investment 19.405325 %, total balance 9784.855005,
# day 703, sell 1 unit at price 15.510000, investment 22.415155 %, total balance 9800.365005,
# day 704: buy 1 unit at price 15.140000, total balance 9785.225005
# day 705, sell 1 unit at price 15.370000, investment 20.549019 %, total balance 9800.595005,
# day 706: buy 1 unit at price 15.340000, total balance 9785.255004
# day 707: buy 1 unit at price 15.350000, total balance 9769.905004
# day 708: buy 1 unit at price 15.220000, total balance 9754.685004
# day 709: buy 1 unit at price 14.920000, total balance 9739.765004
# day 710, sell 1 unit at price 14.850000, investment 16.379311 %, total balance 9754.615004,
# day 711: buy 1 unit at price 14.380000, total balance 9740.235004
# day 712, sell 1 unit at price 14.280000, investment 7.046474 %, total balance 9754.515004,
# day 714: buy 1 unit at price 14.250000, total balance 9740.265004
# day 715: buy 1 unit at price 14.300000, total balance 9725.965003
# day 716: buy 1 unit at price 14.680000, total balance 9711.285003
# day 717: buy 1 unit at price 15.010000, total balance 9696.275003
# day 718: buy 1 unit at price 14.930000, total balance 9681.345003
# day 719: buy 1 unit at price 14.830000, total balance 9666.515003
# day 720: buy 1 unit at price 14.540000, total balance 9651.975003
# day 721, sell 1 unit at price 15.090000, investment 11.283184 %, total balance 9667.065003,
# day 722: buy 1 unit at price 14.950000, total balance 9652.115003
# day 723: buy 1 unit at price 15.290000, total balance 9636.825003
# day 724: buy 1 unit at price 15.460000, total balance 9621.365003
# day 725, sell 1 unit at price 15.280000, investment 11.777613 %, total balance 9636.645003,
# day 726: buy 1 unit at price 14.990000, total balance 9621.655003
# day 727, sell 1 unit at price 14.830000, investment 7.153177 %, total balance 9636.485003,
# day 728, sell 1 unit at price 14.910000, investment 9.391047 %, total balance 9651.395003,
# day 729, sell 1 unit at price 15.380000, investment 11.368571 %, total balance 9666.775003,
# day 730, sell 1 unit at price 15.530000, investment 12.863368 %, total balance 9682.305003,
# day 731: buy 1 unit at price 15.100000, total balance 9667.205002
# day 732: buy 1 unit at price 14.920000, total balance 9652.285002
# day 733, sell 1 unit at price 15.220000, investment 11.338699 %, total balance 9667.505002,
# day 734: buy 1 unit at price 15.380000, total balance 9652.125002
# day 735, sell 1 unit at price 15.410000, investment 9.679713 %, total balance 9667.535002,
# day 736: buy 1 unit at price 15.240000, total balance 9652.295002
# day 737, sell 1 unit at price 15.750000, investment 13.390926 %, total balance 9668.045002,
# day 738: buy 1 unit at price 15.620000, total balance 9652.425003
# day 739, sell 1 unit at price 16.010000, investment 10.110043 %, total balance 9668.435003,
# day 740, sell 1 unit at price 15.530000, investment 4.932429 %, total balance 9683.965003,
# day 741, sell 1 unit at price 15.500000, investment -0.321545 %, total balance 9699.465003,
# day 742: buy 1 unit at price 15.740000, total balance 9683.725003
# day 743, sell 1 unit at price 15.660000, investment 3.434607 %, total balance 9699.385003,
# day 744: buy 1 unit at price 15.610000, total balance 9683.775003
# day 745: buy 1 unit at price 15.660000, total balance 9668.115003
# day 746, sell 1 unit at price 16.209999, investment 5.671440 %, total balance 9684.325002,
# day 747, sell 1 unit at price 16.219999, investment 5.667745 %, total balance 9700.545002,
# day 748, sell 1 unit at price 15.930000, investment 4.664915 %, total balance 9716.475002,
# day 749: buy 1 unit at price 16.580000, total balance 9699.895002
# day 750: buy 1 unit at price 16.590000, total balance 9683.305002
# day 751, sell 1 unit at price 16.600000, investment 11.260056 %, total balance 9699.905002,
# day 752: buy 1 unit at price 16.770000, total balance 9683.135002
# day 753, sell 1 unit at price 16.760000, investment 16.550766 %, total balance 9699.895002,
# day 754: buy 1 unit at price 16.930000, total balance 9682.965002
# day 755, sell 1 unit at price 16.950001, investment 18.947374 %, total balance 9699.915002,
# day 756: buy 1 unit at price 17.250000, total balance 9682.665002
# day 757: buy 1 unit at price 17.650000, total balance 9665.015003
# day 758: buy 1 unit at price 17.730000, total balance 9647.285003
# day 759, sell 1 unit at price 17.549999, investment 22.727266 %, total balance 9664.835002,
# day 760: buy 1 unit at price 18.590000, total balance 9646.245002
# day 761: buy 1 unit at price 18.760000, total balance 9627.485002
# day 762, sell 1 unit at price 18.600000, investment 26.702997 %, total balance 9646.085002,
# day 763: buy 1 unit at price 18.430000, total balance 9627.655002
# day 764: buy 1 unit at price 18.219999, total balance 9609.435003
# day 765: buy 1 unit at price 18.170000, total balance 9591.265003
# day 766: buy 1 unit at price 18.120001, total balance 9573.145002
# day 767: buy 1 unit at price 18.400000, total balance 9554.745002
# day 768: buy 1 unit at price 18.200001, total balance 9536.545002
# day 769: buy 1 unit at price 18.180000, total balance 9518.365001
# day 770: buy 1 unit at price 17.920000, total balance 9500.445001
# day 772, sell 1 unit at price 17.469999, investment 16.389068 %, total balance 9517.915000,
# day 773: buy 1 unit at price 17.639999, total balance 9500.275001
# day 774: buy 1 unit at price 16.879999, total balance 9483.395002
# day 776: buy 1 unit at price 17.440001, total balance 9465.955001
# day 777, sell 1 unit at price 17.650000, investment 18.218347 %, total balance 9483.605001,
# day 778: buy 1 unit at price 17.590000, total balance 9466.015001
# day 779, sell 1 unit at price 17.629999, investment 18.880642 %, total balance 9483.645000,
# day 780: buy 1 unit at price 17.959999, total balance 9465.685001
# day 781, sell 1 unit at price 17.639999, investment 21.320491 %, total balance 9483.325000,
# day 782: buy 1 unit at price 17.500000, total balance 9465.825000
# day 783, sell 1 unit at price 17.830000, investment 19.264215 %, total balance 9483.655000,
# day 784: buy 1 unit at price 18.070000, total balance 9465.585001
# day 785, sell 1 unit at price 17.750000, investment 16.088947 %, total balance 9483.335001,
# day 786: buy 1 unit at price 17.600000, total balance 9465.735000
# day 787, sell 1 unit at price 17.830000, investment 15.329883 %, total balance 9483.565000,
# day 788: buy 1 unit at price 17.940001, total balance 9465.625000
# day 789, sell 1 unit at price 17.610001, investment 17.478325 %, total balance 9483.235000,
# day 791, sell 1 unit at price 17.680000, investment 17.086092 %, total balance 9500.915000,
# day 793: buy 1 unit at price 17.120001, total balance 9483.795000
# day 794: buy 1 unit at price 17.660000, total balance 9466.135000
# day 795, sell 1 unit at price 18.020000, investment 20.777482 %, total balance 9484.155000,
# day 796: buy 1 unit at price 18.459999, total balance 9465.695001
# day 797: buy 1 unit at price 18.170000, total balance 9447.525001
# day 798, sell 1 unit at price 18.280001, investment 18.855660 %, total balance 9465.805002,
# day 799, sell 1 unit at price 17.980000, investment 17.979001 %, total balance 9483.785001,
# day 800, sell 1 unit at price 18.600000, investment 19.078108 %, total balance 9502.385002,
# day 801: buy 1 unit at price 18.680000, total balance 9483.705001
# day 802, sell 1 unit at price 19.080000, investment 21.219823 %, total balance 9502.785001,
# day 803: buy 1 unit at price 18.910000, total balance 9483.875001
# day 805: buy 1 unit at price 19.330000, total balance 9464.545002
# day 806, sell 1 unit at price 19.100000, investment 22.357468 %, total balance 9483.645002,
# day 807, sell 1 unit at price 18.379999, investment 17.369089 %, total balance 9502.025001,
# day 809: buy 1 unit at price 19.070000, total balance 9482.955001
# day 810, sell 1 unit at price 18.709999, investment 12.846798 %, total balance 9501.665000,
# day 811: buy 1 unit at price 18.660000, total balance 9483.005001
# day 812: buy 1 unit at price 18.459999, total balance 9464.545002
# day 813: buy 1 unit at price 18.719999, total balance 9445.825002
# day 814, sell 1 unit at price 18.430000, investment 11.091020 %, total balance 9464.255002,
# day 815: buy 1 unit at price 18.799999, total balance 9445.455003
# day 816, sell 1 unit at price 18.719999, investment 11.627900 %, total balance 9464.175003,
# day 817: buy 1 unit at price 19.010000, total balance 9445.165002
# day 818: buy 1 unit at price 19.370001, total balance 9425.795002
# day 819: buy 1 unit at price 19.340000, total balance 9406.455001
# day 820, sell 1 unit at price 19.209999, investment 13.467211 %, total balance 9425.665000,
# day 821, sell 1 unit at price 19.320000, investment 11.999998 %, total balance 9444.985000,
# day 822: buy 1 unit at price 19.540001, total balance 9425.444999
# day 823, sell 1 unit at price 19.120001, investment 8.328619 %, total balance 9444.565000,
# day 824: buy 1 unit at price 18.410000, total balance 9426.155000
# day 825, sell 1 unit at price 17.309999, investment -2.368867 %, total balance 9443.465000,
# day 826: buy 1 unit at price 18.000000, total balance 9425.465000
# day 827, sell 1 unit at price 18.180000, investment -2.205486 %, total balance 9443.645000,
# day 828, sell 1 unit at price 18.260000, investment -2.665245 %, total balance 9461.905000,
# day 829: buy 1 unit at price 18.030001, total balance 9443.875000
# day 831, sell 1 unit at price 17.850000, investment -3.147042 %, total balance 9461.725000,
# day 832, sell 1 unit at price 17.889999, investment -1.811196 %, total balance 9479.614999,
# day 833, sell 1 unit at price 18.010000, investment -0.880572 %, total balance 9497.625000,
# day 834, sell 1 unit at price 18.110001, investment -0.055189 %, total balance 9515.735000,
# day 835, sell 1 unit at price 18.230000, investment -0.923913 %, total balance 9533.965000,
# day 837: buy 1 unit at price 18.080000, total balance 9515.885000
# day 838, sell 1 unit at price 18.200001, investment 0.000000 %, total balance 9534.085001,
# day 839, sell 1 unit at price 18.110001, investment -0.385037 %, total balance 9552.195001,
# day 840, sell 1 unit at price 18.290001, investment 2.064737 %, total balance 9570.485002,
# day 841: buy 1 unit at price 18.600000, total balance 9551.885002
# day 842, sell 1 unit at price 18.379999, investment 4.195010 %, total balance 9570.265001,
# day 843: buy 1 unit at price 18.360001, total balance 9551.905000
# day 844: buy 1 unit at price 18.190001, total balance 9533.715000
# day 845, sell 1 unit at price 17.840000, investment 5.687210 %, total balance 9551.555000,
# day 846, sell 1 unit at price 17.879999, investment 2.522928 %, total balance 9569.434999,
# day 847, sell 1 unit at price 18.160000, investment 3.240476 %, total balance 9587.594999,
# day 848, sell 1 unit at price 18.170000, investment 1.169271 %, total balance 9605.764999,
# day 849: buy 1 unit at price 18.260000, total balance 9587.504999
# day 850: buy 1 unit at price 18.440001, total balance 9569.064998
# day 851, sell 1 unit at price 18.650000, investment 6.571426 %, total balance 9587.714998,
# day 852, sell 1 unit at price 18.719999, investment 3.597120 %, total balance 9606.434997,
# day 853, sell 1 unit at price 18.670000, investment 6.079544 %, total balance 9625.104997,
# day 854, sell 1 unit at price 18.730000, investment 4.403562 %, total balance 9643.834997,
# day 855, sell 1 unit at price 19.260000, investment 12.499996 %, total balance 9663.094997,
# day 856: buy 1 unit at price 19.370001, total balance 9643.724996
# day 857, sell 1 unit at price 19.340000, investment 9.513026 %, total balance 9663.064996,
# day 858: buy 1 unit at price 19.270000, total balance 9643.794996
# day 859, sell 1 unit at price 19.290001, investment 4.496218 %, total balance 9663.084997,
# day 860, sell 1 unit at price 19.139999, investment 5.338466 %, total balance 9682.224996,
# day 861, sell 1 unit at price 19.290001, investment 3.265528 %, total balance 9701.514997,
# day 862: buy 1 unit at price 19.400000, total balance 9682.114997
# day 863, sell 1 unit at price 19.500000, investment 3.120043 %, total balance 9701.614997,
# day 864: buy 1 unit at price 19.660000, total balance 9681.954998
# day 865: buy 1 unit at price 19.889999, total balance 9662.064998
# day 866: buy 1 unit at price 20.540001, total balance 9641.524997
# day 867, sell 1 unit at price 20.450001, investment 5.794107 %, total balance 9661.974998,
# day 868: buy 1 unit at price 20.230000, total balance 9641.744998
# day 869: buy 1 unit at price 20.379999, total balance 9621.364999
# day 870: buy 1 unit at price 20.670000, total balance 9600.694999
# day 871: buy 1 unit at price 20.190001, total balance 9580.504999
# day 872, sell 1 unit at price 20.530001, investment 7.656010 %, total balance 9601.034999,
# day 873: buy 1 unit at price 20.760000, total balance 9580.274999
# day 874, sell 1 unit at price 20.690001, investment 10.878889 %, total balance 9600.965000,
# day 875: buy 1 unit at price 21.190001, total balance 9579.774999
# day 876: buy 1 unit at price 21.250000, total balance 9558.524999
# day 877, sell 1 unit at price 21.290001, investment 15.330455 %, total balance 9579.815000,
# day 878: buy 1 unit at price 21.450001, total balance 9558.364999
# day 879: buy 1 unit at price 21.190001, total balance 9537.174999
# day 880: buy 1 unit at price 20.959999, total balance 9516.215000
# day 881: buy 1 unit at price 21.070000, total balance 9495.145000
# day 882: buy 1 unit at price 21.110001, total balance 9474.034999
# day 883: buy 1 unit at price 21.180000, total balance 9452.854999
# day 884, sell 1 unit at price 20.950001, investment 11.912401 %, total balance 9473.805000,
# day 885: buy 1 unit at price 21.340000, total balance 9452.465000
# day 886: buy 1 unit at price 21.049999, total balance 9431.415000
# day 888: buy 1 unit at price 21.389999, total balance 9410.025001
# day 889, sell 1 unit at price 21.129999, investment 12.393617 %, total balance 9431.155000,
# day 890: buy 1 unit at price 20.860001, total balance 9410.295000
# day 891: buy 1 unit at price 20.639999, total balance 9389.655000
# day 892, sell 1 unit at price 20.940001, investment 10.152553 %, total balance 9410.595001,
# day 893, sell 1 unit at price 21.309999, investment 10.015480 %, total balance 9431.905000,
# day 894: buy 1 unit at price 21.330000, total balance 9410.575000
# day 895, sell 1 unit at price 21.730000, investment 12.357804 %, total balance 9432.305000,
# day 896: buy 1 unit at price 21.709999, total balance 9410.595001
# day 897: buy 1 unit at price 21.709999, total balance 9388.885002
# day 898: buy 1 unit at price 21.850000, total balance 9367.035001
# day 899, sell 1 unit at price 21.920000, investment 12.180138 %, total balance 9388.955001,
# day 900, sell 1 unit at price 22.120001, investment 20.152097 %, total balance 9411.075002,
# day 901, sell 1 unit at price 22.270000, investment 23.722225 %, total balance 9433.345003,
# day 902: buy 1 unit at price 22.879999, total balance 9410.465003
# day 903: buy 1 unit at price 22.639999, total balance 9387.825004
# day 904: buy 1 unit at price 22.580000, total balance 9365.245004
# day 905: buy 1 unit at price 22.809999, total balance 9342.435005
# day 906: buy 1 unit at price 22.879999, total balance 9319.555006
# day 907, sell 1 unit at price 22.780001, investment 26.344980 %, total balance 9342.335006,
# day 908: buy 1 unit at price 22.990000, total balance 9319.345006
# day 909: buy 1 unit at price 23.320000, total balance 9296.025007
# day 910: buy 1 unit at price 23.629999, total balance 9272.395008
# day 911: buy 1 unit at price 23.400000, total balance 9248.995008
# day 912: buy 1 unit at price 23.559999, total balance 9225.435009
# day 913: buy 1 unit at price 23.480000, total balance 9201.955009
# day 914, sell 1 unit at price 23.549999, investment 30.254421 %, total balance 9225.505008,
# day 918, sell 1 unit at price 23.980000, investment 28.924726 %, total balance 9249.485008,
# day 920, sell 1 unit at price 23.730000, investment 29.248359 %, total balance 9273.215007,
# day 926, sell 1 unit at price 23.430000, investment 28.807035 %, total balance 9296.645008,
